# %%
import sys
#!{sys.executable} -m pip install gensim
import numpy as np
import pandas as pd
import nltk
#nltk.download('punkt') # one time execution
import re
import csv

# %%
import pprint
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# %%
import matplotlib.pyplot as plt
from PyPDF3 import PdfFileWriter, PdfFileReader

output = PdfFileWriter()
#input1 = PdfFileReader(open("Seige_of_Vicksburg_Sample_OCR.pdf", "rb"))
input1 = PdfFileReader(open("BaselIII_20131011_ffr.pdf", "rb"))
pd.set_option('display.max_colwidth', -1)

# %%
pdfReader = input1

# %%
pdfReader.numPages
# Out:
# 275

# %%
df = pd.DataFrame()

# %%
d=[]
i=0
#for i in range(pdfReader.numPages):

for i in range(50):
    pageObj = pdfReader.getPage(i)
    d.append({'Page_Num': i+1, 'Content':pageObj.extractText()})

    
df = pd.DataFrame(d)
r_nwnt=re.compile("[\n\t\r]")
df5 = pd.DataFrame((r_nwnt.sub("",s)) for i,s in enumerate(sentences))
df5
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0
# 0     Vol.
# 1     78 Friday, No.
# ...

# %%
df7 = pd.DataFrame()
s1=[]
lst1 =["Investment","Holding"]
for z in lst1:
    s1.append({'Page_Num': df5[df5[0].str.contains(z)]['Page_Num'], 'Content': df5[df5[0].str.contains(z)]['Content']}
        )

df7=pd.DataFrame(s1)
#print(df7.values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'Page_Num'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
#df7.iloc[0,0]
df7[0:]

# %%
f=[]

for i in range(pdfReader.getNumPages()):
    pageObj = pdfReader.getPage(i)
    #d.append({'Page_Num': i+1, 'Content': sent_tokenize(pageObj.extractText())})
    
    #d = [y for x in d for y in x] 
    z=(sent_tokenize(pageObj.extractText()))
    r_nwnt=re.compile("[\n\t\r]")
    z2 = [(r_nwnt.sub("",s)) for i,s in enumerate(z)]
    
    #print(z3)
    for z1 in z2 :

        f.append({'Page_Num': i+1, 'Content': z1}) 
df6 = pd.DataFrame(f)

# %%
df6
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Content  \
# 0     Vol.
# 1     78 Friday, No.
# 2     198 October 11, 2013 Part II Department of the Treasury Office of the Comptroller of the Currency 12 CFR Parts 3, 5, 6, et al.
# ...

# %%
df17=pd.DataFrame()
df18=df6[df6['Content'].str.contains("Investment")]['Content']
df17=df6[df6['Content'].str.contains("Investment")]
df17
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
lst1 =["Investment","Holding"]
s12=[]
df19=pd.DataFrame()
for z in lst1:
    #s12.append({'Page_Num':(df6[df6['Content'].str.contains(z)])})
    s12.append({'Page_Num': df6[df6['Content'].str.contains(z)]['Page_Num'], 'Content': df6[df6['Content'].str.contains(z)]['Content']})
    #s12.append(df6[df6['Content'].str.contains(z)])
     #
    df_1=pd.DataFrame(s1)
    print(s1)
    df19.append(df_1)
    

#df17=df6[df6['Content'].str.contains("Investment")]
#df17
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
for z in lst1:
    s1.append({'Page_Num': df5[df5[0].str.contains(z)]['Page_Num'], 'Content': df5[df5[0].str.contains(z)]['Content']}
    df7=pd.DataFrame(s1)
        )

df7=pd.DataFrame(s1)

# %%
df19
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
fig = plt.figure(figsize=(12,10))
ax1 = fig.add_subplot(111, projection='3d')

ax1.scatter(ranks,ranks,s=100)
plt.scatter(ranks,ranks, s=2,c="Red", alpha=0.5)

# %%
writer = pd.ExcelWriter('Summary.xlsx')
df1.to_excel(writer,'Summary')
writer.save()
